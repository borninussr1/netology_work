# %% [markdown]
# Добрый день. Задание делал в trinket.io (Jupyter Notebook на работе не поставить). Сначало написал программу без функций. В trinket.io программа работает, но как только копирую её в Jupyter Notebook начинаются проблемы с отступами.
# сделать из программы функцию тоже не получилось.
# https://trinket.io/library/trinkets/4fdb5965db  ссылка на программу в trinket.io.

# %%
documents = [
{'type': 'passport', 'number': '2207 876234', 'name': 'Василий Гупкин'},
{'type': 'invoice', 'number': '11-2', 'name': 'Геннадий Покемонов'},
{'type': 'insurance', 'number': '10006', 'name': 'Аристарх Павлов'}
]

directories = {
'1': ['2207 876234', '11-2'],
'2': ['10006'],
'3': []
}

print('Введите команду:')
comand= input()
  
if comand=='p':
    print('Введите номер документа:')
    Number1=input()
    ok=None
    for i in documents:
        if i['number']==Number1:
            print('Владелец документа:', i['name'])
            ok=1
    if ok!=1:
        print('Документ не найден в базе')
            
            
elif comand=='s':
    print('Введите номер документа:')
    Number1=input()
    ok=None
    for i in directories:
        for j in directories[i]:
            if j==Number1:
                print('Документ хранится на полке:', i)
                ok=1
    if ok!=1:
        print('Документ не найден в базе')


elif comand=='l':
    p=None
    for item in documents:
        for i in directories:
            if item['number'] in directories[i]:
                p=i
                print('№:' ,item['number'], 'тип:',item['type'], 'владелец:',item['name'], 'полка хранения:',p)
                
elif comand=='as':
  print('Введите номер полки:')
  shelf_number=input()
  for i in directories:
    if shelf_number==i:
      print('Такая полка уже существует. Текущий перечень полок: 1, 2, 3.')
      break
    else:
      print('Полка добавлена. Текущий перечень полок: 1, 2, 3,', shelf_number)
      break


elif comand=='ds':
  print('Введите номер полки:')
  shelf_number=input()
  for i in directories:
    if shelf_number==i:
      if len(directories[i])==0:
        del directories[i]
        print(directories)
      else:
        print('На полке есть документа, удалите их перед удалением полки. Текущий перечень полок: 1, 2, 3.')
    else:
      print('Такой полки не существует. Текущий перечень полок: 1, 2, 3.')
      break
else:
  print('Такой команды ещё нет, но мы работаем над этим. Отнеситесь к этому с пониманием.')
